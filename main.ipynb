# %%
import src.UI as UI

# %%
data_preperation = UI.DataPreperationUI()
data_preperation
# Out:
# DataPreperationUI(children=(UploadFileWidget(children=(HBox(children=(Label(value='Please, select your data fi…

# %%
data_preperation.data_file.file
# Out:
#    Header_1  Header_2  Header_3
# 0         1         2         3
# 1         4         5         6
# 2         7         8         9
